# %% [markdown]
# ## Scratch Notebook for Creation in Bokeh

# %%
# import functions
import argparse, datetime, os, sys, time
import pandas as pd
import os

os.chdir('../')
from tools import load_groupfile, query_api, filterIQM, merge_dfs

# %%
import seaborn as sns
